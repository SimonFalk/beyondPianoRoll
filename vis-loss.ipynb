# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open("results/cnn-training-220425a/fold_0_a-seq-35eps-nostandard-trainable-noextend-dropout0.3_history.pickle", 'rb') as file_pi:
    h = pickle.load(file_pi)

# %%
import matplotlib
font = {'family' : 'normal',
        'size'   : 14}
matplotlib.rc('font', **font)

plt.plot(h["loss"])
plt.plot(h["val_loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Training loss", "Validation loss"])
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

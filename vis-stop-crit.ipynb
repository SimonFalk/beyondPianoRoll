# %%
# Plotting - stopping criterion investigation

import matplotlib.pyplot as plt
plt.errorbar(x=epochs, y=f_at_ep.mean(0), yerr=f_at_ep.std(0))
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
n, bins, _ = plt.hist(np.argmax(f_at_ep, axis=1))
plt.show()
plt.bar(epochs, n, width=8.0)
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("# recordings where F-measure is maximized")
# Out:
# Text(0, 0.5, '# recordings where F-measure is maximized')

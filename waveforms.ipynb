# %%
# %load_ext autoreload
# %autoreload 2
import os
from reader import get_wav_paths
from util import MirAudioSegment
import librosa
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Open all files in directory
sample_rate = 22050
paths = get_wav_paths(num_per_dir=5)
for label in paths.keys():
    for path in paths[label]:
        track, sr = librosa.load(path)
        plt.plot(track)
        plt.show()

signals = {label: librosa.load(path)}

# %%
cats = ["A", "B", "C", "D"]
instrument = "violin"
for cat in cats:
    label = cat + "_" + instrument
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.8/site-packages/pydub/audio_segment.py in _repr_html_(self)
#    1392                     </audio>
#    1393                   """
# -> 1394         fh = self.export()
#    1395         data = base64.b64encode(fh.read()).decode('ascii')
#    1396         return src.format(base64=data)
#
# ~/anaconda3/lib/python3.8/site-packages/pydub/audio_segment.py in export(self, out_f, format, codec, bitrate, parameters, tags, id3v2_version, cover)
#     961         # read stdin / write stdout
# ...
